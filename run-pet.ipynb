# %%
# %cd /home/sanala/Juputer try/PET/
# Out:
# /home/sanala/Juputer try/PET

# %%
# !python3 cli.py --method pet --pattern_ids 0 1 2 3 4 \
--data_dir '/home/sanala/Juputer try/PET/data-fsl/amh/10sample/' \
--model_type  xlm-roberta \
--model_name_or_path 'Davlan/afro-xlmr-large' \
--task_name 'topic-classification' \
--output_dir '/home/sanala/Juputer try/PET/results/amh/model-pet-10-Davlan-afro-xlmr-large/' \
--do_train \
--do_eval \
--sc_repetitions 1

# %%
 # !python3 cli.py --method ipet --pattern_ids 0 1 2 3 4 \
--data_dir '/home/sanala/Juputer try/PET/data-fsl/amh/10sample/' \
--model_type xlm-roberta \
--model_name_or_path 'Davlan/afro-xlmr-large' \
--task_name 'topic-classification' \
--output_dir '/home/sanala/Juputer try/PET/results/amh/model-ipet-10-Davlan-afro-xlmr-large/' \
--do_train \
--do_eval \
--sc_repetitions 1
# Out:
# 2023-01-26 20:53:12.260719: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2023-01-26 20:53:12.260759: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# ...
